# %% [markdown]
# #### Pandas assignment

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Q1 Use Pandas' read_csv function open it as a DataFrame

# %%
Data1 = pd.read_csv('police_project.csv');
Data1
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %% [markdown]
# ###  Q2What does each row represent

# %%
rows = Data1.head(10)
#rows

# %% [markdown]
# ### Q3 How to get the basic statistics of all the columns

# %%
stat = Data1.describe()
#stat
# Out:
#        county_name  driver_age_raw    driver_age
# count          0.0    86414.000000  86120.000000
# mean           NaN     1970.491228     34.011333
# std            NaN      110.914909     12.738564
# min            NaN        0.000000     15.000000
# 25%            NaN     1967.000000     23.000000
# 50%            NaN     1980.000000     31.000000
# 75%            NaN     1987.000000     43.000000
# max            NaN     8801.000000     99.000000

# %% [markdown]
# ### Q4 How to check the shape of the data set

# %%
Data1.shape
# Out:
# (91741, 15)

# %% [markdown]
# #### Check the type of columns

# %%
Data1.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
Data1['driver_race'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Q 5 How to check the missing values

# %%
Data1.isnull()
# Out:
#        stop_date  stop_time  county_name  driver_gender  driver_age_raw  \
# 0          False      False         True          False           False
# 1          False      False         True          False           False
# 2          False      False         True          False           False
# 3          False      False         True          False           False
# 4          False      False         True          False           False
# ...          ...        ...          ...            ...             ...
# 91736      False      False         True          False           False
# 91737      False      False         True          False           False
# 91738      False      False         True          False           False
# 91739      False      False         True          False           False
# 91740      False      False         True          False           False
#
#        driver_age  driver_race  violation_raw  violation  search_conducted  \
# ...

# %%
Null_values=Data1.notnull()

# %% [markdown]
# ### Q6  sum of each column

# %%
Col_sum=Data1.sum()
Col_sum
# Out:
# stop_date             2005-01-022005-01-182005-01-232005-02-202005-0...
# stop_time             01:5508:1523:1517:1510:0009:4517:3013:2010:151...
# county_name                                                           0
# driver_age_raw                                              1.70278e+08
# driver_age                                                  2.92906e+06
# search_conducted                                                   3196
# is_arrested                                                        2929
# drugs_related_stop                                                  815
# dtype: object

# %% [markdown]
# ### Q 7 Dropping columns that only contains missing values

# %%
Drop_col = Data1.dropna(axis=1)
Drop_col
# Out:
#         stop_date stop_time  search_conducted  drugs_related_stop
# 0      2005-01-02     01:55             False               False
# 1      2005-01-18     08:15             False               False
# 2      2005-01-23     23:15             False               False
# 3      2005-02-20     17:15             False               False
# 4      2005-03-14     10:00             False               False
# ...           ...       ...               ...                 ...
# 91736  2015-12-31     20:27             False               False
# 91737  2015-12-31     20:35             False               False
# 91738  2015-12-31     20:45             False               False
# 91739  2015-12-31     21:42             False               False
# 91740  2015-12-31     22:46             False               False
#
# [91741 rows x 4 columns]

# %% [markdown]
# ### Q8  Do the men or womwn speed more often

# %%
gender =Data1['driver_gender'].value_counts()
gender
# Out:
# M    62895
# F    23511
# Name: driver_gender, dtype: int64

# %%
gender.idxmax()
# Out:
# 'M'

# %% [markdown]
# ### Q9  Which year had the least number of stops?

# %%
kk=Data1['stop_date']= pd.to_datetime(Data1['stop_date'])
kk
# Out:
# 0       2005-01-02
# 1       2005-01-18
# 2       2005-01-23
# 3       2005-02-20
# 4       2005-03-14
#            ...
# 91736   2015-12-31
# 91737   2015-12-31
# 91738   2015-12-31
# 91739   2015-12-31
# 91740   2015-12-31
# Name: stop_date, Length: 91741, dtype: datetime64[ns]

# %%
result=Data1.groupby([Data1['stop_date'].dt.year]).agg({'count'})
print(result)
# Out:
#           stop_date stop_time county_name driver_gender driver_age_raw  \
#               count     count       count         count          count
# stop_date
# 2005           2558      2558           0          2505           2506
# 2006          10639     10639           0         10141          10147
# 2007           9476      9476           0          8905           8906
# 2008           8752      8752           0          8151           8151
# 2009           7908      7908           0          7237           7237
# 2010           7561      7561           0          6995           6995
# 2011           8126      8126           0          7575           7575
# 2012          10970     10970           0         10396          10395
# 2013           7924      7924           0          7421           7421
# 2014           9228      9228           0          8849           8849
# 2015           8599      8599           0          8231           8232
#
# ...

# %%
result['stop_date'].max()
# Out:
# count    10970
# dtype: int64

# %%
result['stop_date'].min()
# Out:
# count    2558
# dtype: int64

# %% [markdown]
# ### Q 10 Does gender affects who get searched?

# %%
Data1[['driver_gender','search_conducted']]
# Out:
#       driver_gender  search_conducted
# 0                 M             False
# 1                 M             False
# 2                 M             False
# 3                 M             False
# 4                 F             False
# ...             ...               ...
# 91736             M             False
# 91737             F             False
# 91738             M             False
# 91739             M             False
# 91740             M             False
#
# [91741 rows x 2 columns]

# %%
Data1['search_conducted'].value_counts()
# Out:
# False    88545
# True      3196
# Name: search_conducted, dtype: int64

# %%
Female= (Data1.search_conducted).sum()
Female
# Out:
# 3196

# %% [markdown]
# ### Q11 How does drug activity change by time of day?

# %%
Extra=Data1[['stop_time','drugs_related_stop']]
Extra
# Out:
#       stop_time  drugs_related_stop
# 0         01:55               False
# 1         08:15               False
# 2         23:15               False
# 3         17:15               False
# 4         10:00               False
# ...         ...                 ...
# 91736     20:27               False
# 91737     20:35               False
# 91738     20:45               False
# 91739     21:42               False
# 91740     22:46               False
#
# [91741 rows x 2 columns]

# %%
Activity=Data1.stop_time.mask(Data1.drugs_related_stop).dropna() # prints only false values
Activity
# Out:
# 0        01:55
# 1        08:15
# 2        23:15
# 3        17:15
# 4        10:00
#          ...
# 91736    20:27
# 91737    20:35
# 91738    20:45
# 91739    21:42
# 91740    22:46
# Name: stop_time, Length: 90926, dtype: object

# %%
activity2= Data1[Data1.drugs_related_stop].stop_time ## shows only true values
activity2
# Out:
# 40       00:00
# 41       00:00
# 118      01:20
# 139      00:20
# 219      23:30
#          ...
# 91194    14:48
# 91253    10:33
# 91284    14:10
# 91672    11:05
# 91700    08:51
# Name: stop_time, Length: 815, dtype: object

# %%
len(activity2)
# Out:
# 815

# %% [markdown]
# ### Q12 Do more stops occur at night

# %%
stop_time=Data1['stop_time']
stop_time
# Out:
# 0        01:55
# 1        08:15
# 2        23:15
# 3        17:15
# 4        10:00
#          ...
# 91736    20:27
# 91737    20:35
# 91738    20:45
# 91739    21:42
# 91740    22:46
# Name: stop_time, Length: 91741, dtype: object

# %%
k=Data1['stop_time']
k
# Out:
# 0        01:55
# 1        08:15
# 2        23:15
# 3        17:15
# 4        10:00
#          ...
# 91736    20:27
# 91737    20:35
# 91738    20:45
# 91739    21:42
# 91740    22:46
# Name: stop_time, Length: 91741, dtype: object

# %%
v=Data1[['h','m']] = Data1['stop_time'].astype(str).str.split(':', expand=True).astype(int)
v
# Out:
#         0   1
# 0       1  55
# 1       8  15
# 2      23  15
# 3      17  15
# 4      10   0
# ...    ..  ..
# 91736  20  27
# 91737  20  35
# 91738  20  45
# 91739  21  42
# 91740  22  46
#
# [91741 rows x 2 columns]

# %%
Data8to12 = Data1[Data1['h'].between(20,24,inclusive=True)] # from 8 to 12
#Data8to12

# %%
Data1to4=Data1[Data1['h'].between(1,4,inclusive = True)] # from 12 to 4 early morning
Data1to4
# Out:
#        stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0     2005-01-02     01:55          NaN             M          1985.0
# 22    2005-08-08     02:09          NaN             M          1955.0
# 24    2005-08-28     01:00          NaN             M          1979.0
# 29    2005-09-26     01:05          NaN           NaN             NaN
# 43    2005-10-01     01:00          NaN             M          1985.0
# ...          ...       ...          ...           ...             ...
# 91579 2015-12-22     03:35          NaN             F          1945.0
# 91603 2015-12-24     04:07          NaN             M          1976.0
# 91630 2015-12-27     02:54          NaN             F          1990.0
# 91660 2015-12-28     02:28          NaN           NaN             NaN
# 91694 2015-12-30     02:21          NaN             F          1994.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# ...

# %%
len1=len(Data1to4)  # length of data in between 1 am till 4 am

# %%
len2=len(Data8to12) # length of data in between 8 to 12

# %%
len_n=len1+len2 # total amount of data in between 8 to 4 am

# %%
print(len(Data1) > len_n)
# Out:
# True
